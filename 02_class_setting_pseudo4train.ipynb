# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Read 4train data

# %%
import pandas as pd
df = pd.read_csv('drug_cleaned.csv')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'name', 'resolution', 'path', 'has_image', 'im_file'], dtype='object')

# %%
df.rename(columns={'Unnamed: 0':'idx'}, inplace=True)

# %%
df.columns
# Out:
# Index(['idx', 'name', 'resolution', 'path', 'has_image', 'im_file'], dtype='object')

# %% [markdown]
# # Read group data

# %%
group = pd.read_csv('group.csv')

# %%
group.rename(columns={'Unnamed: 0':'group_idx'}, inplace=True)

# %%
group
# Out:
#       group_idx                                               name
# 0             0  12 HR Acetazolamide 500 MG Extended Release Or...
# 1             1  12 HR Acetazolamide 500 MG Extended Release Or...
# 2             2  12 HR Albuterol 4 MG Extended Release Oral Tablet
# 3             3  12 HR Amoxicillin 1000 MG / Clavulanate 62.5 M...
# 4             4  12 HR Bupropion Hydrochloride 100 MG Extended ...
# ...         ...                                                ...
# 2106       2106  {7 (Ethinyl Estradiol 0.035 MG / norgestimate ...
# 2107       2107  {7 (Ethinyl Estradiol 0.035 MG / norgestimate ...
# 2108       2108  {7 (lamotrigine 100 MG Disintegrating Oral Tab...
# 2109       2109  {84 (Ethinyl Estradiol 0.03 MG / Levonorgestre...
# 2110       2110  {84 (Ethinyl Estradiol 0.03 MG / Levonorgestre...
#
# [2111 rows x 2 columns]

# %% [markdown]
# # Merge name and group

# %%
df1 = pd.merge(df, group, left_on='name', right_on='name', how='left')

# %%
df1
# Out:
#          idx                                        name       resolution  \
# 0          0  Loperamide Hydrochloride 2 MG Oral Capsule        RXNAV 120
# 1          1              Minocycline 50 MG Oral Capsule        RXNAV 120
# 2          2            Nortriptyline 10 MG Oral Capsule        RXNAV 120
# 3          3            Nortriptyline 25 MG Oral Capsule        RXNAV 120
# 4          4            Nortriptyline 50 MG Oral Capsule        RXNAV 120
# ...      ...                                         ...              ...
# 47497  51979        Enalapril Maleate 2.5 MG Oral Tablet  RXBASE ORIGINAL
# 47498  51980                  quinapril 5 MG Oral Tablet  RXBASE ORIGINAL
# 47499  51981         trospium chloride 20 MG Oral Tablet  RXBASE ORIGINAL
# 47500  51982               metaxalone 400 MG Oral Tablet  RXBASE ORIGINAL
# 47501  51983              naratriptan 2.5 MG Oral Tablet  RXBASE ORIGINAL
#
#                                                     path  has_image  \
# 0      image/images/gallery/120/00093-0311-01_RXNAVIM...       True
# 1      image/images/gallery/120/00093-3165-01_RXNAVIM...       True
# 2      image/images/gallery/120/00093-0810-01_RXNAVIM...       True
# 3      image/images/gallery/120/00093-0811-01_RXNAVIM...       True
# 4      image/images/gallery/120/00093-0812-01_RXNAVIM...       True
# ...                                                  ...        ...
# 47497  image/images/gallery/original/16714-0442-01_NL...       True
# 47498  image/images/gallery/original/31722-0267-90_NL...       True
# 47499  image/images/gallery/original/00574-0145-60_NL...       True
# 47500  image/images/gallery/original/64720-0126-10_NL...       True
# 47501  image/images/gallery/original/23155-0055-19_NL...       True
#
#                                                  im_file  group_idx
# 0      RXNAV-120_00093-0311-01_RXNAVIMAGE10_26211358.jpg       1052
# 1      RXNAV-120_00093-3165-01_RXNAVIMAGE10_36231B28.jpg       1137
# 2      RXNAV-120_00093-0810-01_RXNAVIMAGE10_24231228.jpg       1193
# 3      RXNAV-120_00093-0811-01_RXNAVIMAGE10_20231018.jpg       1194
# 4      RXNAV-120_00093-0812-01_RXNAVIMAGE10_2D2316D8.jpg       1195
# ...                                                  ...        ...
# 47497  RXBASE-ORIGINAL_16714-0442-01_NLMIMAGE10_DC4D6...        708
# 47498  RXBASE-ORIGINAL_31722-0267-90_NLMIMAGE10_EA507...       1844
# 47499  RXBASE-ORIGINAL_00574-0145-60_NLMIMAGE10_3C519...       1959
# 47500  RXBASE-ORIGINAL_64720-0126-10_NLMIMAGE10_C6506...       1749
# 47501  RXBASE-ORIGINAL_23155-0055-19_NLMIMAGE10_66453...       1775
#
# [47502 rows x 7 columns]

# %% [markdown]
# # Change class from 0(drug) to group

# %%
import os
import shutil
from tqdm.notebook import tqdm
def rmakedir(path):
  if os.path.exists(path):
    shutil.rmtree(path)
    os.makedirs(path)
  else:
    os.makedirs(path)

# %%
dst_path = './pseudo_lables'
rmakedir(dst_path)
for i in tqdm(range(len(df1))):
  f, g = df1.im_file.iloc[i], str(df1.group_idx.iloc[i])
#   print(f)
  src = os.path.join('../runs/detect/detect_4train_pseudolabel/labels', f[:-3]+'txt')
  dst = os.path.join(dst_path, f[:-3]+'txt')
  with open(src, 'r') as txt:
      txt = txt.read().splitlines()
      with open(dst, 'w') as dst_file:
          for line in txt:
              cl, x, y, w, h = [i for i in line.split(' ')]
              dst_file.writelines(' '.join([g, x, y, w, h])+'\n')
# Out:
#   0%|          | 0/47502 [00:00<?, ?it/s]
