# %% [markdown]
# # Environment Preparation

# %%
# !conda create -n yolov10 python=3.9

# %%
# !pip install -q git+https://github.com/THU-MIG/yolov10.git

# %% [markdown]
# # Train model

# %%
# !yolo task=detect mode=train epochs=50 batch=40 plots=True model=weights/yolov10n.pt data=ultralytics/cfg/datasets/drug2k.yaml

# %% [markdown]
# # Validation

# %% [markdown]
# !yolo val model=runs/detect/train/weights/best.pt data=ultralytics/cfg/datasets/drug2k.yaml imgsz=640 batch=60 conf=0.25 iou=0.6 device=0

# %%
# !yolo val model=runs/detect/train/weights/yolov10.pt data=ultralytics/cfg/datasets/drug2k.yaml imgsz=640 batch=50 conf=0.25 iou=0.6 device=0
# Out:
# Ultralytics YOLOv8.1.34 🚀 Python-3.9.19 torch-2.0.1+cu117 CUDA:0 (NVIDIA A100 80GB PCIe, 81051MiB)
# YOLOv10n summary (fused): 285 layers, 4043954 parameters, 0 gradients, 15.6 GFLOPs
# val: Scanning /mnt/batch/tasks/shared/LS_root/mounts/clusters/pongsakba1/code/Us
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       4750       9500      0.933      0.955       0.99      0.984
#                      0       4750         16          1      0.728      0.879      0.879
#                      1       4750          2      0.892          1      0.995      0.995
#                      2       4750          2          1          0      0.995      0.995
#                      3       4750          2      0.455          1      0.995      0.945
#                      4       4750          4      0.892        0.5       0.77       0.77
#                      5       4750          4          1          0      0.414      0.411
# ...

# %% [markdown]
# # Export .pt to .onnx

# %%
# !yolo export model=runs/detect/train/weights/yolov10.pt format=onnx
# Out:
# Ultralytics YOLOv8.1.34 🚀 Python-3.9.19 torch-2.0.1+cu117 CPU (AMD EPYC 7V13 64-Core Processor)
# YOLOv10n summary (fused): 285 layers, 4043954 parameters, 0 gradients, 15.6 GFLOPs
#
# PyTorch: starting from 'runs/detect/train/weights/yolov10.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 300, 6) (8.1 MB)
#
# ONNX: starting export with onnx 1.14.0 opset 17...
# ============= Diagnostic Run torch.onnx.export version 2.0.1+cu117 =============
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================
#
# ONNX: export success ✅ 1.3s, saved as 'runs/detect/train/weights/yolov10.onnx' (11.5 MB)
#
# Export complete (3.3s)
# Results saved to /mnt/batch/tasks/shared/LS_root/mounts/clusters/pongsakba1/code/Users/pongsak.b/yolov10/runs/detect/train/weights
# Predict:         yolo predict task=detect model=runs/detect/train/weights/yolov10.onnx imgsz=640
# ...
